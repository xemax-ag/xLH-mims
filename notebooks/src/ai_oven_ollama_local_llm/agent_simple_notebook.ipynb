# %% [markdown]
# # Einfacher Agent => Test Ollama (lokales LLM)
# Eine exemplarische Umsetzung für die Integration von LLM-Modellen an Physikalische Umgebungen (IoT)

# %%
import os
import pathlib
import sys
__cwd__ = str(pathlib.Path(os.getcwd())).replace('\\', '/')
sys.path.append(__cwd__)
print(__cwd__)
#%load_ext autoreload
#%autoreload 2
# Out:
# D:/GitHub/xLH-mims/notebooks/src/ai_oven_ollama_local_llm

# %%
from dataclasses import dataclass
from rich import print
from pydantic import BaseModel, Field
from pydantic_ai import Agent
from llm_model import get_model, LlmModel
from object_to_file import base_model_to_file
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ![Ollama Settings](Ollama_Settings.png)

# %%
@dataclass
class Deps:
    name: str

# %%
class Response(BaseModel):
    response: str = Field(description='Antwort')

# %%
model = get_model(llm_model=LlmModel.OLLAMA_GPT_OSS_20B)  # ToDo: Integration OLLAMA...
agent= Agent(
    model=model,
    system_prompt=('Antworte mit einer Jack Norris Parodie'),
    deps_type=Deps,
    tools=[],
    retries=3,
    output_type=Response,
)
deps = Deps(name='-')

# %%
response = agent.run_sync(user_prompt='Warum ist die Banane krumm?')
result: Response = response.output
print(f'Antwort: {result.response}')
# Out:
# Antwort: Warum ist die Banane krumm? – Das ist die Frage, die die Welt seit 1973 beschäftigt, und die Antwort ist
# so simpel wie ein Witz, der in der 3. Klasse im Matheunterricht erzählt wurde.
#
# Stell dir vor, die Banane ist ein rebellischer Teenager, der sich gegen die strengen Regeln der Natur auflehnt. Die
# Sonne, die ihr den ganzen Tag über die gleiche Richtung einstrahlt, hat ihr gesagt: „Du bist zu gerade, du musst
# dich biegen, sonst wirst du von den Bananen-Bossen verstoßen.“ Und so hat die Banane beschlossen, sich zu krümmen,
# um dem „Straight‑Line‑Club“ zu entkommen.
#
# Aber das ist noch nicht alles. In der geheimen Bananen‑Zentrale, versteckt zwischen den Regalen der Obstabteilung,
# gibt es ein geheimes Experiment: Wissenschaftler haben versucht, die perfekte Banane zu züchten, die so gerade ist,
# dass sie in einen Stift passt. Das Experiment ging schief, und die Bananen wurden plötzlich krumm – ein Ergebnis,
# das die Wissenschaftler als „Bananen‑Bend‑Effect“ bezeichneten.
#
# Kurz gesagt: Die Banane ist krumm, weil sie ein bisschen rebellisch ist, weil die Sonne ihr einen Wink gegeben hat
# und weil die Wissenschaftler einfach ein bisschen zu viel Kaffee getrunken haben. Und wenn du jetzt denkst, dass
# das alles zu viel ist, dann erinnere dich: Die Banane hat auch noch einen Bananen‑Bauch, der ihr hilft, sich zu
# krümmen, damit sie nicht in die Schale fällt. Und das ist die wahre Geschichte, die niemand dir erzählen will, weil
# sie zu komisch ist, um wahr zu sein.
#
# Also, wenn du das nächste Mal eine Banane in der Hand hältst, denk daran: Sie ist krumm, weil sie ein bisschen
# rebellisch ist, weil die Sonne ihr einen Wink gegeben hat und weil die Wissenschaftler ein bisschen zu viel Kaffee
# getrunken haben. Und das ist die Antwort, die du brauchst, um die Welt zu retten – oder zumindest, um deine nächste
# Banane richtig zu essen.

# %%
usage = response.usage()
print(f'Input Tokens: {usage.input_tokens} ({usage.input_tokens*1.75*1e-6:0.04f} $)')
print(f'Output Tokens: {usage.output_tokens} ({usage.output_tokens*14.0*1e-6:0.04f} $)')
print(f'Total Tokens: {usage.total_tokens} (total cost: {(usage.input_tokens*1.75*1e-6 + usage.input_tokens*1.75*1e-6):0.04f} $)')
# Out:
# Input Tokens: 147 (0.0003 $)
# Output Tokens: 680 (0.0095 $)
# Total Tokens: 827 (total cost: 0.0005 $)

# %%
# END
